# %% [markdown]
# # 단어 빈도 그래프
#
# NLTK는 구텐베르크 프로젝트(저작권 만료된 영어소설 제공) 중 일부를 제공

# %%
import nltk

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
# 파일 제목 가져오기

from nltk.corpus import gutenberg

file_names = gutenberg.fileids()
print(file_names)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
# 이상한 나라의 앨리스 읽어오기

doc_alice = gutenberg.open('carroll-alice.txt').read()
print('사용된 문자의 수:', len(doc_alice))
print(doc_alice[:1000])     # 앞의 1000자만 출력
# Out:
# 사용된 문자의 수: 144395
# [Alice's Adventures in Wonderland by Lewis Carroll 1865]
#
# CHAPTER I. Down the Rabbit-Hole
#
# Alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into the
# book her sister was reading, but it had no pictures or conversations in
# it, 'and what is the use of a book,' thought Alice 'without pictures or
# conversation?'
#
# So she was considering in her own mind (as well as she could, for the
# hot day made her feel very sleepy and stupid), whether the pleasure
# of making a daisy-chain would be worth the trouble of getting up and
# picking the daisies, when suddenly a White Rabbit with pink eyes ran
# close by her.
#
# There was nothing so VERY remarkable in that; nor did Alice think it so
# VERY much out of the way to hear the Rabbit say to itself, 'Oh dear!
# Oh dear! I shall be late!' (when she thought it over afterwards, it
# occurred to her that she ought to have wondered at this, but at the time
# it all seemed quite natural); but

# %% [markdown]
# **토큰화 (Tokenizing) 진행**
#
# 단어 토큰화 vs 정규표현식 토큰화<br>
# 괄호, 구두점 등이 있어 정규표현식 토큰화를 사용한다.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

word_tokens_alice = word_tokenize(doc_alice)
print('토큰의 개수:', len(word_tokens_alice))
print('Token sample:')
print(word_tokens_alice[:20])
# Out:
# 토큰의 개수: 33310
# Token sample:
# ['[', 'Alice', "'s", 'Adventures', 'in', 'Wonderland', 'by', 'Lewis', 'Carroll', '1865', ']', 'CHAPTER', 'I', '.', 'Down', 'the', 'Rabbit-Hole', 'Alice', 'was', 'beginning']

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer("[\w']{1,}") 

reg_tokens_alice = tokenizer.tokenize(doc_alice)
print('토큰의 개수:', len(reg_tokens_alice))
print('Token sample:')
print(reg_tokens_alice[:20])
# Out:
# 토큰의 개수: 27803
# Token sample:
# ["Alice's", 'Adventures', 'in', 'Wonderland', 'by', 'Lewis', 'Carroll', '1865', 'CHAPTER', 'I', 'Down', 'the', 'Rabbit', 'Hole', 'Alice', 'was', 'beginning', 'to', 'get', 'very']

# %% [markdown]
# **어간 추출 (stemming) vs 표제어 추출 (lemmatization)**
#
# 사용 단어의 빈도를 확인할 것이기 때문에 실제로 사용은 하지 않는다.

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# 포터 스태밍

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stem_tokens_alice = [stemmer.stem(token) for token in reg_tokens_alice]
print('어간 추출 후 토큰의 개수:', len(stem_tokens_alice))
print('Token sample:')
print(stem_tokens_alice[:20])
# Out:
# 어간 추출 후 토큰의 개수: 27803
# Token sample:
# ["alice'", 'adventur', 'in', 'wonderland', 'by', 'lewi', 'carrol', '1865', 'chapter', 'I', 'down', 'the', 'rabbit', 'hole', 'alic', 'wa', 'begin', 'to', 'get', 'veri']

# %%
# 표제어 추출

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lem_tokens_alice = [lemmatizer.lemmatize(token) for token in reg_tokens_alice]
print('표제어 추출 후 토큰의 개수:', len(lem_tokens_alice))
print('Token sample:')
print(lem_tokens_alice[:20])
# Out:
# 표제어 추출 후 토큰의 개수: 27803
# Token sample:
# ["Alice's", 'Adventures', 'in', 'Wonderland', 'by', 'Lewis', 'Carroll', '1865', 'CHAPTER', 'I', 'Down', 'the', 'Rabbit', 'Hole', 'Alice', 'wa', 'beginning', 'to', 'get', 'very']

# %% [markdown]
# **불용어 제거**

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

english_stops = set(stopwords.words('english'))     # 반복이 되지 않도록 set으로 변환

result_alice = [word for word in reg_tokens_alice if word not in english_stops]     # stopwords를 제외한 단어들만으로 list를 생성

print('불용어 제거후 토큰의 개수:', len(result_alice))
print('Token sample:')
print(result_alice[:20])
# Out:
# 불용어 제거후 토큰의 개수: 15324
# Token sample:
# ["Alice's", 'Adventures', 'Wonderland', 'Lewis', 'Carroll', '1865', 'CHAPTER', 'I', 'Down', 'Rabbit', 'Hole', 'Alice', 'beginning', 'get', 'tired', 'sitting', 'sister', 'bank', 'nothing', 'twice']

# %% [markdown]
# **품사 태깅을 이용하여 단어 선별**
#
# 의미가 있을 법한 명사, 고유명사, 동사, 형용사, 부사만 선택

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
my_tag_set = ['NN', 'NNP', 'RB', 'VB', 'VBD', 'JJ']
my_words = [word for word, tag in nltk.pos_tag(result_alice) if tag in my_tag_set]
print(my_words)

# 딕셔너리로 각 단어의 빈도수 체크
alice_word_count = dict()
for word in my_words:
    alice_word_count[word] = alice_word_count.get(word, 0) + 1

print('단어의 개수:', len(alice_word_count))

sorted_word_count = sorted(alice_word_count, key=alice_word_count.get, reverse=True)    # key 값 기준으로 내림차순 정렬

print("빈도수 상위 20개 단어:")
for key in sorted_word_count[:20]:  # 빈도수 상위 20개의 단어를 출력
    print(f'{repr(key)}: {alice_word_count[key]}', end=', ')
# Out:
# ["Alice's", 'Adventures', 'Wonderland', 'Lewis', 'Carroll', 'CHAPTER', 'Rabbit', 'Hole', 'Alice', 'get', 'tired', 'sister', 'bank', 'nothing', 'twice', 'peeped', 'book', 'sister', 'reading', 'book', 'Alice', 'So', 'mind', 'well', 'hot', 'day', 'feel', 'sleepy', 'stupid', 'pleasure', 'daisy', 'chain', 'worth', 'trouble', 'suddenly', 'White', 'Rabbit', 'pink', 'ran', 'close', 'nothing', 'VERY', 'remarkable', 'Alice', 'think', 'VERY', 'much', 'way', 'hear', 'Rabbit', 'dear', 'Oh', 'dear', 'late', 'thought', 'occurred', 'time', 'seemed', 'quite', 'natural', 'Rabbit', 'actually', 'A', 'WATCH', 'OUT', 'OF', 'ITS', 'WAISTCOAT', 'POCKET', 'looked', 'hurried', 'Alice', 'started', 'mind', 'never', 'rabbit', 'waistcoat', 'pocket', 'watch', 'take', 'burning', 'curiosity', 'ran', 'field', 'fortunately', 'time', 'see', 'pop', 'large', 'rabbit', 'hole', 'hedge', 'moment', 'went', 'Alice', 'never', 'world', 'get', 'rabbit', 'hole', 'went', 'straight', 'tunnel', 'way', 'dipped', 'suddenly', 'suddenly', 'Alice', 'moment', 'think', 'found', 'deep', 'well', 'Either', 'well', 'deep', 'fell', 'slowly', 'plenty', 'time', 'went', 'look', 'wonder', 'happen', 'next', 'First', 'tried', 'dark', 'anything', 'looked', 'well', 'noticed', 'book', 'saw', 'pegs', 'took', 'jar', 'labelled', "MARMALADE'", 'great', 'disappointment', 'drop', 'jar', 'fear', 'somebody', 'managed', 'put', 'fell', 'past', "'Well", 'thought', 'Alice', 'fall', 'think', 'nothing', 'stairs', 'How', 'brave', "they'll", 'think', 'home', 'anything', 'even', 'fell', 'top', 'house', 'Which', 'likely', 'true', 'Down', 'Would', 'fall', 'NEVER', 'end', 'wonder', 'many', "I've", 'time', 'said', 'aloud', "'I", 'somewhere', 'centre', 'earth', 'Let', 'see', 'thousand', 'Alice', 'learnt', 'several', 'sort', 'VERY', 'good', 'opportunity', 'knowledge', 'listen', 'still', 'good', 'practice', 'right', 'distance', 'Latitude', 'Longitude', "I've", 'got', 'Alice', 'idea', 'Latitude', 'Longitude', 'thought', 'nice', 'grand', 'Presently', 'began', "'I", 'wonder', 'fall', 'right', 'THROUGH', 'earth', 'How', 'funny', "it'll", 'downward', 'rather', 'glad', 'WAS', 'listening', 'time', 'sound', 'right', 'word', 'ask', 'name', 'country', 'know', 'Please', "Ma'am", 'New', 'Zealand', 'Australia', 'tried', 'spoke', 'fancy', 'CURTSEYING', 'air', 'Do', 'think', 'manage', 'ignorant', 'little', 'girl', "she'll", "it'll", 'never', 'perhaps', 'see', 'somewhere', 'Down', 'nothing', 'else', 'Alice', 'soon', 'began', 'miss', 'much', 'night', 'Dinah', 'cat', 'hope', 'remember', 'saucer', 'milk', 'tea', 'time', 'Dinah', 'dear', 'mice', 'air', "I'm", 'afraid', 'catch', 'bat', 'mouse', 'Alice', 'began', 'get', 'rather', 'sleepy', 'went', 'dreamy', 'sort', 'way', 'eat', 'sometimes', "'Do", 'see', 'question', 'much', 'way', 'put', 'felt', 'dream', 'hand', 'hand', 'Dinah', 'earnestly', 'Dinah', 'tell', 'truth', 'ever', 'eat', 'bat', 'suddenly', 'thump', 'came', 'heap', 'fall', 'Alice', 'bit', 'hurt', 'jumped', 'moment', 'looked', 'dark', 'overhead', 'long', 'passage', 'White', 'Rabbit', 'still', 'sight', 'moment', 'lost', 'away', 'went', 'Alice', 'wind', 'time', 'hear', 'turned', 'corner', 'late', 'close', 'turned', 'Rabbit', 'long', 'low', 'hall', 'lit', 'row', 'roof', 'hall', 'Alice', 'way', 'side', 'door', 'walked', 'sadly', 'middle', 'ever', 'get', 'Suddenly', 'came', 'upon', 'little', 'legged', 'table', 'solid', 'glass', 'nothing', 'tiny', 'golden', 'key', "Alice's", 'first', 'thought', 'belong', 'large', 'key', 'small', 'rate', 'open', 'However', 'second', 'time', 'round', 'came', 'upon', 'low', 'curtain', 'noticed', 'behind', 'little', 'door', 'fifteen', 'high', 'tried', 'little', 'golden', 'key', 'lock', 'great', 'delight', 'fitted', 'Alice', 'opened', 'door', 'found', 'led', 'small', 'passage', 'much', 'rat', 'hole', 'knelt', 'looked', 'along', 'passage', 'garden', 'ever', 'saw', 'How', 'longed', 'get', 'dark', 'hall', 'wander', 'bright', 'even', 'get', 'head', 'doorway', 'even', 'head', 'go', 'thought', 'poor', 'Alice', "'it ...
# 단어의 개수: 2260
# 빈도수 상위 20개 단어:
# 'said': 456, 'Alice': 385, 'little': 125, 'went': 83, 'time': 68, 'Queen': 66, 'began': 58, 'King': 57, 'Turtle': 57, 'way': 56, 'Mock': 56, 'thought': 55, 'Gryphon': 55, 'Hatter': 54, 'quite': 53, 'much': 51, 'thing': 49, 'head': 47, 'voice': 46, 'got': 44,

# %% [markdown]
# **그래프 그리기**
#
# `matplotlib` 사용

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 모든 단어에 대해 그래프를 그리면 그래프 해석이 힘들 수 있으며, 어떤 단어의 빈도수가 높은지 단어를 표시하려 하면 가독성이 떨어지며, 2^16 pixel을 넘어가게 되면 에러가 발생한다.

# %%
w = [alice_word_count[key] for key in sorted_word_count] # 정렬된 단어 리스트에 대해 빈도수를 가져와서 리스트 생성
plt.plot(w)
plt.show()

# %% [markdown]
# 한계점으로 인해 빈도가 높은 상위 몇개의 단어만 그래프화하여 볼 수 있다.

# %%
n = sorted_word_count[:20][::-1]    # 빈도수 상위 20개의 단어를 추출하여 역순으로 정렬
w = [alice_word_count[key] for key in n]
plt.barh(range(len(n)),w,tick_label=n)  # 수평 막대그래프 (단어의 가독성을 위함)
plt.show()
